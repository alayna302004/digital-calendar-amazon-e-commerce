# %% [markdown]
# <a href="https://colab.research.google.com/github/alayna302004/digital-calendar-amazon-e-commerce/blob/main/digital_calendar_amazon_e_commerce_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Digital Calendar Amazon E-Commerce Data Analysis - by Alayna Smith

# %%
import pandas as pd
import numpy as np
import altair as alt

# %% [markdown]
# ## Original Dataset:

# %%
df = pd.read_csv('Digital Calendar Helium 10 Export.csv')
df
# Out:
#      Display Order                                    Product Details  \
# 0              1.0  Amazon Echo Show 5 (newest model), Smart displ...
# 1              2.0  Amazon Echo Show 15 (newest model), Full HD 15...
# 2              3.0  ($) Skylight Calendar: 15-inch Wall Planner Di...
# 3              4.0  ($) Cozyla 32 Inch Digital Calendar Wall Touch...
# 4              5.0  ($) Digital Calender 15.6 Inch Smart Wall Cale...
# ..             ...                                                ...
# 149          150.0  ($) American Lifetime 【New 2024】 Dementia Cloc...
# 150          151.0  ($) Digital Alarm Clock with Date and Day of W...
# 151          152.0  ($) Véfaîî 19 Alarms Dementia Clock 8 Inch Lar...
# 152          153.0  ($) 11.5 Inch Extra Large Digital Talking Cloc...
# 153          154.0  ($) Digital Calendar Dementia Alarm Clock with...
#
#            ASIN                                         URL  \
# 0    B09B2SBHQK  https://www.amazon.com/dp/B09B2SBHQK?psc=1
# 1    B0C5DPSW5Y  https://www.amazon.com/dp/B0C5DPSW5Y?psc=1
# 2    B0C9V811L6  https://www.amazon.com/dp/B0C9V811L6?psc=1
# 3    B0DHCJM694  https://www.amazon.com/dp/B0DHCJM694?psc=1
# 4    B0FBGRHT84  https://www.amazon.com/dp/B0FBGRHT84?psc=1
# ..          ...                                         ...
# 149  B019G79V1Q  https://www.amazon.com/dp/B019G79V1Q?psc=1
# 150  B0DYCNG8QK  https://www.amazon.com/dp/B0DYCNG8QK?psc=1
# 151  B098TPSX3P  https://www.amazon.com/dp/B098TPSX3P?psc=1
# 152  B0C4K6711K  https://www.amazon.com/dp/B0C4K6711K?psc=1
# 153  B0DL9LYJJT  https://www.amazon.com/dp/B0DL9LYJJT?psc=1
#
#                                              Image URL              Brand  \
# 0    https://m.media-amazon.com/images/I/71j-zo5Suh...             Amazon
# 1    https://m.media-amazon.com/images/I/817u3lFg9I...             Amazon
# 2    https://m.media-amazon.com/images/I/71Kxk8es6d...           Skylight
# 3    https://m.media-amazon.com/images/I/71Rzv9CJ46...             cozyla
# 4    https://m.media-amazon.com/images/I/71+ux8O9fH...       Dragon Touch
# ..                                                 ...                ...
# 149  https://m.media-amazon.com/images/I/71KvhQqHJ5...  American Lifetime
# 150  https://m.media-amazon.com/images/I/61hmpDJsMe...            Mitoart
# 151  https://m.media-amazon.com/images/I/61du9l-GZ9...             Véfaîî
# 152  https://m.media-amazon.com/images/I/51tQd1setg...             MASSII
# 153  https://m.media-amazon.com/images/I/61FRS9ux2k...              SSINI
#
#     Price  $ Parent Level Sales ASIN Sales Recent Purchases  ...  \
# 0      89.99             33,703     10,241           10,000  ...
# 1     299.99              9,691      7,017            4,000  ...
# 2     319.99             14,941     14,855            8,000  ...
# 3     899.99                165        115              100  ...
# 4     299.99                 37          4              NaN  ...
# ..       ...                ...        ...              ...  ...
# 149    59.95              2,877      1,191            1,000  ...
# 150    29.99              1,000        673              500  ...
# 151    44.59                233        180              100  ...
# 152    58.99              1,926        640              400  ...
# 153    24.29              1,451        992            1,000  ...
#
#                Size Tier Fulfillment               Dimensions Weight  \
# 0    Large Standard-Size         AMZ    5.87 x 3.39 x 5.30 in   1.48
# 1    Large Standard-Size         AMZ  17.76 x 4.25 x 12.09 in   8.25
# 2    Large Standard-Size         FBA  17.83 x 3.62 x 11.26 in   8.09
# 3        Large and Bulky         FBA  33.50 x 5.75 x 22.00 in  31.25
# 4        Large and Bulky         AMZ  20.12 x 2.44 x 11.50 in   5.91
# ..                   ...         ...                      ...    ...
# 149  Large Standard-Size         FBA    9.21 x 2.64 x 7.32 in   1.37
# 150  Large Standard-Size         FBA   10.39 x 1.85 x 6.97 in   0.97
# 151  Large Standard-Size         FBA   11.06 x 1.93 x 7.72 in   1.19
# 152  Large Standard-Size         FBA   13.11 x 1.93 x 7.83 in   1.48
# 153  Large Standard-Size         FBA   11.42 x 2.01 x 6.89 in   0.99
#
#     ABA Most Clicked  Creation Date              Sponsored  Best Seller  \
# 0                NaN   May 17, 2023  Featured Amazon Brand          Yes
# 1                NaN   Nov 20, 2024  Featured Amazon Brand           No
# 2                NaN   Jun 30, 2023              Sponsored          Yes
# 3                NaN   Sep 18, 2024              Sponsored           No
# 4                NaN   May 30, 2025              Sponsored           No
# ..               ...            ...                    ...          ...
# 149              NaN   Jan 10, 2016              Sponsored           No
# 150              NaN   Feb 24, 2025              Sponsored           No
# 151              NaN    Jul 7, 2021              Sponsored           No
# 152              NaN    May 7, 2023              Sponsored           No
# 153              NaN    Dec 2, 2024              Sponsored           No
#
#     Seller Age (mo)             Seller
# 0                25             Amazon
# 1                 7                NaN
# 2                24     Skylight Frame
# 3                 9       Cozyla Album
# 4                 1             Amazon
# ..              ...                ...
# 149             113  American Lifetime
# 150               4     Mitoart Direct
# 151              47           TENGFEEL
# 152              25        MASSII Care
# 153               6            Norbiri
#
# [154 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154 entries, 0 to 153
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Display Order          154 non-null    float64
#  1   Product Details        154 non-null    object
#  2   ASIN                   154 non-null    object
#  3   URL                    154 non-null    object
#  4   Image URL              154 non-null    object
#  5   Brand                  154 non-null    object
#  6   Price  $               154 non-null    object
#  7   Parent Level Sales     154 non-null    object
#  8   ASIN Sales             154 non-null    object
#  9   Recent Purchases       96 non-null     object
#  10  Parent Level Revenue   154 non-null    object
#  11  ASIN Revenue           154 non-null    object
#  12  Title Char. Count      154 non-null    int64
#  13  BSR                    150 non-null    object
#  14  Seller Country/Region  150 non-null    object
#  15  Fees  $                152 non-null    float64
#  16  Active Sellers         154 non-null    int64
#  17  Ratings                149 non-null    float64
#  18  Review Count           154 non-null    object
#  19  Images                 149 non-null    float64
#  20  Review velocity        146 non-null    object
#  21  Buy Box                152 non-null    object
#  22  Category               149 non-null    object
#  23  Size Tier              153 non-null    object
#  24  Fulfillment            152 non-null    object
#  25  Dimensions             153 non-null    object
#  26  Weight                 153 non-null    float64
#  27  ABA Most Clicked       0 non-null      float64
#  28  Creation Date          154 non-null    object
#  29  Sponsored              58 non-null     object
#  30  Best Seller            154 non-null    object
#  31  Seller Age (mo)        154 non-null    int64
#  32  Seller                 152 non-null    object
# dtypes: float64(6), int64(3), object(24)
# memory usage: 39.8+ KB

# %% [markdown]
# ## Cleaned Dataset:

# %%
excluded_columns = ['Product Details', 'URL', 'Image URL', 'Weight',
                    'Parent Level Sales', 'Parent Level Revenue',
                    'Review velocity', 'Size Tier', 'Dimensions']
filtered_df = df.drop(columns=excluded_columns)
columns_to_convert = ['ASIN Sales', 'ASIN Revenue', 'BSR', 'Review Count',
                      'Price  $', 'Title Char. Count', 'Recent Purchases']

for column in columns_to_convert:
  # Replace 'N/A' with np.nan (NaN represents null in pandas)
  filtered_df[column] = filtered_df[column].replace('N/A', np.nan)
  # Remove commas from the string values
  filtered_df[column] = filtered_df[column].astype(str).str.replace(',', '', regex=False)
  # Convert to float, coercing errors to NaN
  filtered_df[column] = pd.to_numeric(filtered_df[column], errors='coerce')
# Fill empty 'Category' with 'Unknown'
filtered_df['Category'].fillna('Unknown', inplace=True)
# Fill empty 'Sponsored' with 'None'
filtered_df['Sponsored'].fillna('None', inplace=True)

filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154 entries, 0 to 153
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Display Order          154 non-null    float64
#  1   ASIN                   154 non-null    object
#  2   Brand                  154 non-null    object
#  3   Price  $               154 non-null    float64
#  4   ASIN Sales             154 non-null    int64
#  5   Recent Purchases       96 non-null     float64
#  6   ASIN Revenue           154 non-null    float64
#  7   Title Char. Count      154 non-null    int64
#  8   BSR                    150 non-null    float64
#  9   Seller Country/Region  150 non-null    object
#  10  Fees  $                152 non-null    float64
#  11  Active Sellers         154 non-null    int64
#  12  Ratings                149 non-null    float64
#  13  Review Count           154 non-null    int64
#  14  Images                 149 non-null    float64
#  15  Buy Box                152 non-null    object
#  16  Category               154 non-null    object
#  17  Fulfillment            152 non-null    object
#  18  ABA Most Clicked       0 non-null      float64
#  19  Creation Date          154 non-null    object
#  20  Sponsored              154 non-null    object
#  21  Best Seller            154 non-null    object
#  22  Seller Age (mo)        154 non-null    int64
#  23  Seller                 152 non-null    object
# dtypes: float64(9), int64(5), object(10)
# memory usage: 29.0+ KB
# /tmp/ipython-input-5-2232474760.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   filtered_df['Category'].fillna('Unknown', inplace=True)
# /tmp/ipython-input-5-2232474760.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   filtered_df['Sponsored'].fillna('None', inplace=True)

# %%
filtered_df
# Out:
#      Display Order        ASIN              Brand  Price  $  ASIN Sales  \
# 0              1.0  B09B2SBHQK             Amazon     89.99       10241
# 1              2.0  B0C5DPSW5Y             Amazon    299.99        7017
# 2              3.0  B0C9V811L6           Skylight    319.99       14855
# 3              4.0  B0DHCJM694             cozyla    899.99         115
# 4              5.0  B0FBGRHT84       Dragon Touch    299.99           4
# ..             ...         ...                ...       ...         ...
# 149          150.0  B019G79V1Q  American Lifetime     59.95        1191
# 150          151.0  B0DYCNG8QK            Mitoart     29.99         673
# 151          152.0  B098TPSX3P             Véfaîî     44.59         180
# 152          153.0  B0C4K6711K             MASSII     58.99         640
# 153          154.0  B0DL9LYJJT              SSINI     24.29         992
#
#      Recent Purchases  ASIN Revenue  Title Char. Count       BSR  \
# 0             10000.0     849928.22                 93      18.0
# 1              4000.0    2104934.91                116       NaN
# 2              8000.0    4738562.71                193     430.0
# 3               100.0      97937.25                198   40994.0
# 4                 NaN       1114.56                191     269.0
# ..                ...           ...                ...       ...
# 149            1000.0      69560.00                192   10946.0
# 150             500.0      20182.69                165   44791.0
# 151             100.0       8039.33                187  118779.0
# 152             400.0      36731.25                196   16758.0
# 153            1000.0      27306.65                171   21712.0
#
#     Seller Country/Region  ...  Images            Buy Box  \
# 0                     AMZ  ...     7.0             Amazon
# 1                     AMZ  ...     NaN                NaN
# 2                      US  ...    10.0     Skylight Frame
# 3                      US  ...     8.0       Cozyla Album
# 4                     AMZ  ...     8.0             Amazon
# ..                    ...  ...     ...                ...
# 149                    US  ...     7.0  American Lifetime
# 150                    CN  ...     6.0     Mitoart Direct
# 151                    CN  ...     9.0           TENGFEEL
# 152                    CN  ...     6.0        MASSII Care
# 153                    CN  ...     8.0            Norbiri
#
#                    Category  Fulfillment  ABA Most Clicked Creation Date  \
# 0                   Unknown          AMZ               NaN  May 17, 2023
# 1                   Unknown          AMZ               NaN  Nov 20, 2024
# 2           Office Products          FBA               NaN  Jun 30, 2023
# 3           Office Products          FBA               NaN  Sep 18, 2024
# 4    Digital Picture Frames          AMZ               NaN  May 30, 2025
# ..                      ...          ...               ...           ...
# 149          Home & Kitchen          FBA               NaN  Jan 10, 2016
# 150          Home & Kitchen          FBA               NaN  Feb 24, 2025
# 151          Home & Kitchen          FBA               NaN   Jul 7, 2021
# 152          Home & Kitchen          FBA               NaN   May 7, 2023
# 153          Home & Kitchen          FBA               NaN   Dec 2, 2024
#
#                  Sponsored Best Seller  Seller Age (mo)             Seller
# 0    Featured Amazon Brand         Yes               25             Amazon
# 1    Featured Amazon Brand          No                7                NaN
# 2                Sponsored         Yes               24     Skylight Frame
# 3                Sponsored          No                9       Cozyla Album
# 4                Sponsored          No                1             Amazon
# ..                     ...         ...              ...                ...
# 149              Sponsored          No              113  American Lifetime
# 150              Sponsored          No                4     Mitoart Direct
# 151              Sponsored          No               47           TENGFEEL
# 152              Sponsored          No               25        MASSII Care
# 153              Sponsored          No                6            Norbiri
#
# [154 rows x 24 columns]

# %% [markdown]
# ## First Visualization: Revenue vs. Brand (top 10 brands)

# %%
# top ten brands, based on ASIN revenue
top_rev_brands = filtered_df.groupby('Brand')['ASIN Revenue'].sum().nlargest(10).reset_index()
top_rev_brands
# Out:
#                Brand  ASIN Revenue
# 0           Skylight   28628284.40
# 1             Amazon    5059798.04
# 2        Cozyla Mate     864142.68
# 3             cozyla     679350.05
# 4             BQQJDD     569037.34
# 5       Dragon Touch     424981.67
# 6             LOOFII     252005.52
# 7            DASFIWO     149456.93
# 8          Herncptar     142699.56
# 9  American Lifetime     139120.00

# %%
chart1 = alt.Chart(top_rev_brands).mark_bar().encode(
    x=alt.X('Brand', sort='-y'),
    y='ASIN Revenue',
    color='Brand'
).properties(
    width=600,
    height=500,
    title='Top 10 Brands by ASIN Revenue'
)
chart1
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Second Visualization: Revenue vs. Category

# %%
# Group by 'Category' and sum 'ASIN Revenue'
category_revenue = filtered_df.groupby('Category')['ASIN Revenue'].sum().reset_index()
category_revenue
# Out:
#                   Category  ASIN Revenue
# 0   Digital Picture Frames     285833.52
# 1              Electronics     204521.96
# 2           Home & Kitchen     955950.40
# 3  Industrial & Scientific       1955.90
# 4          Office Products   32041409.97
# 5                  Unknown    5059798.04

# %%
chart2 = alt.Chart(category_revenue).mark_bar().encode(
    x=alt.X('Category', sort='-y'),
    y='ASIN Revenue',
    color='Category'
  ).properties(
    width=600,
    height=500,
    title='ASIN Revenue by Category'
  )
chart2
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Third Visualization: Revenue vs. Product Price
# This shows which price ranges generate the most revenue

# %%
price_revenue = filtered_df.groupby('Price  $')['ASIN Revenue'].sum().reset_index()
price_revenue
# Out:
#     Price  $  ASIN Revenue
# 0       5.99      19968.63
# 1       7.99       2914.23
# 2       8.55      13120.90
# 3       9.99      15752.26
# 4      14.99       4993.77
# ..       ...           ...
# 66    899.99    1082947.56
# 67    909.99      40175.29
# 68   1799.00      22247.26
# 69   2099.00       5586.60
# 70   2499.00      88668.46
#
# [71 rows x 2 columns]

# %%
chart3 = alt.Chart(price_revenue).mark_line().encode(
    x='Price  $',
    y='ASIN Revenue'
).properties(
    width=800,
    title='ASIN Revenue by Price'
)
chart3
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Fourth Visualization: Revenue vs. Sponsorship

# %%
sponsored_revenue = filtered_df.groupby('Sponsored')['ASIN Revenue'].sum().reset_index()
sponsored_revenue
# Out:
#                Sponsored  ASIN Revenue
# 0  Featured Amazon Brand    2954863.13
# 1                   None    9769028.96
# 2              Sponsored   25825577.70

# %%
chart4 = alt.Chart(sponsored_revenue).mark_bar().encode(
    x=alt.X('Sponsored', sort='-y'),
    y='ASIN Revenue',
    color='Sponsored'
  ).properties(
    width=400,
    height=500,
    title='ASIN Revenue by Sponsorship'
  )
chart4
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Fifth Visualization: Revenue vs. Number of Images

# %%
images_revenue = filtered_df.groupby('Images')['ASIN Revenue'].sum().reset_index()
images_revenue
# Out:
#    Images  ASIN Revenue
# 0     1.0       2009.88
# 1     6.0     417073.25
# 2     7.0    2334158.36
# 3     8.0    2058533.19
# 4     9.0     669315.59
# 5    10.0   28854854.94
# 6    12.0        452.28
# 7    14.0       3202.48

# %%
chart5 = alt.Chart(images_revenue).mark_line().encode(
    x='Images',
    y='ASIN Revenue'
).properties(
    width=800,
    title='ASIN Revenue by Number of Images'
)
chart5
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Sixth Visualization: Revenue vs. Fulfillment Method

# %%
fulfillment_revenue = filtered_df.groupby('Fulfillment')['ASIN Revenue'].sum().reset_index()
fulfillment_revenue
# Out:
#   Fulfillment  ASIN Revenue
# 0         AMZ    5484779.71
# 1         FBA   33064690.08

# %%
chart6 = alt.Chart(fulfillment_revenue).mark_bar().encode(
    x=alt.X('Fulfillment', sort='-y'),
    y='ASIN Revenue',
    color='Fulfillment'
  ).properties(
    width=400,
    height=500,
    title='ASIN Revenue by Fulfillment Method'
  )
chart6
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Seventh Visualization: Revenue vs. Seller Country/Region

# %%
sellers_revenue = filtered_df.groupby('Seller Country/Region')['ASIN Revenue'].sum().reset_index()
sellers_revenue
# Out:
#   Seller Country/Region  ASIN Revenue
# 0                   AMZ    5484779.71
# 1                    CN    3394826.38
# 2                    HK      12625.58
# 3                    US   29641173.40

# %%
chart7 = alt.Chart(sellers_revenue).mark_bar().encode(
    x=alt.X('Seller Country/Region', sort='-y'),
    y='ASIN Revenue',
    color='Seller Country/Region'
  ).properties(
    width=600,
    height=500,
    title='ASIN Revenue by Seller Location'
  )
chart7
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Eigth Visualization: Revenue vs. Display Order

# %%
chart8 = alt.Chart(filtered_df).mark_line().encode(
    x='Display Order',
    y='ASIN Revenue',
  ).properties(
    width=800,
    height=400,
    title='ASIN Revenue by Display Order'
  )
chart8
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Ninth Visualization: Ratings vs. Price

# %%
price_ratings = filtered_df.groupby('Price  $')['Ratings'].sum().reset_index()
price_ratings.head()
# Out:
#    Price  $  Ratings
# 0      5.99      4.8
# 1      7.99      4.4
# 2      8.55      4.0
# 3      9.99      4.7
# 4     14.99      4.5

# %%
chart9 = alt.Chart(price_ratings).mark_line().encode(
    x='Price  $',
    y='Ratings'
).properties(
    width=800,
    height=400,
    title='Fees by Ratings'
) + alt.Chart(price_ratings).mark_circle().encode(
    x='Price  $',
    y='Ratings'
)
chart9
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## Tenth Visualization: Recent Purchases vs. Seller Age

# %%
age_recent = filtered_df.groupby('Seller Age (mo)')['Recent Purchases'].sum().reset_index()
age_recent.head()
# Out:
#    Seller Age (mo)  Recent Purchases
# 0                0               0.0
# 1                1             500.0
# 2                2             500.0
# 3                3            3300.0
# 4                4             650.0

# %%
chart10 = alt.Chart(age_recent).mark_line().encode(
    x='Seller Age (mo)',
    y='Recent Purchases'
).properties(
    width=800,
    height=400,
    title='Recent Purchases by Seller Age'
) + alt.Chart(age_recent).mark_circle().encode(
    x='Seller Age (mo)',
    y='Recent Purchases'
)
chart10
# Out:
# alt.LayerChart(...)

# %%
looker_df = df.copy()

# Fill empty 'Category' with 'Unknown'
looker_df['Category'].fillna('Unknown', inplace=True)
# Fill empty 'Sponsored' with 'None'
looker_df['Sponsored'].fillna('None', inplace=True)
# Fill empty 'Seller' with 'Unknown'
looker_df['Seller'].fillna('Unknown', inplace=True)


looker_df.to_csv('edited_digital_calendar_data.csv', index=False)
# Out:
# /tmp/ipython-input-33-1917456378.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   looker_df['Category'].fillna('Unknown', inplace=True)
# /tmp/ipython-input-33-1917456378.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   looker_df['Sponsored'].fillna('None', inplace=True)
# /tmp/ipython-input-33-1917456378.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   looker_df['Seller'].fillna('Unknown', inplace=True)

# %%
looker_df.head()
# Out:
#    Display Order                                    Product Details  \
# 0            1.0  Amazon Echo Show 5 (newest model), Smart displ...
# 1            2.0  Amazon Echo Show 15 (newest model), Full HD 15...
# 2            3.0  ($) Skylight Calendar: 15-inch Wall Planner Di...
# 3            4.0  ($) Cozyla 32 Inch Digital Calendar Wall Touch...
# 4            5.0  ($) Digital Calender 15.6 Inch Smart Wall Cale...
#
#          ASIN                                         URL  \
# 0  B09B2SBHQK  https://www.amazon.com/dp/B09B2SBHQK?psc=1
# 1  B0C5DPSW5Y  https://www.amazon.com/dp/B0C5DPSW5Y?psc=1
# 2  B0C9V811L6  https://www.amazon.com/dp/B0C9V811L6?psc=1
# 3  B0DHCJM694  https://www.amazon.com/dp/B0DHCJM694?psc=1
# 4  B0FBGRHT84  https://www.amazon.com/dp/B0FBGRHT84?psc=1
#
#                                            Image URL         Brand Price  $  \
# 0  https://m.media-amazon.com/images/I/71j-zo5Suh...        Amazon    89.99
# 1  https://m.media-amazon.com/images/I/817u3lFg9I...        Amazon   299.99
# 2  https://m.media-amazon.com/images/I/71Kxk8es6d...      Skylight   319.99
# 3  https://m.media-amazon.com/images/I/71Rzv9CJ46...        cozyla   899.99
# 4  https://m.media-amazon.com/images/I/71+ux8O9fH...  Dragon Touch   299.99
#
#   Parent Level Sales ASIN Sales Recent Purchases  ...            Size Tier  \
# 0             33,703     10,241           10,000  ...  Large Standard-Size
# 1              9,691      7,017            4,000  ...  Large Standard-Size
# 2             14,941     14,855            8,000  ...  Large Standard-Size
# 3                165        115              100  ...      Large and Bulky
# 4                 37          4              NaN  ...      Large and Bulky
#
#   Fulfillment               Dimensions Weight ABA Most Clicked  Creation Date  \
# 0         AMZ    5.87 x 3.39 x 5.30 in   1.48              NaN   May 17, 2023
# 1         AMZ  17.76 x 4.25 x 12.09 in   8.25              NaN   Nov 20, 2024
# 2         FBA  17.83 x 3.62 x 11.26 in   8.09              NaN   Jun 30, 2023
# 3         FBA  33.50 x 5.75 x 22.00 in  31.25              NaN   Sep 18, 2024
# 4         AMZ  20.12 x 2.44 x 11.50 in   5.91              NaN   May 30, 2025
#
#                Sponsored  Best Seller Seller Age (mo)          Seller
# 0  Featured Amazon Brand          Yes              25          Amazon
# 1  Featured Amazon Brand           No               7         Unknown
# 2              Sponsored          Yes              24  Skylight Frame
# 3              Sponsored           No               9    Cozyla Album
# 4              Sponsored           No               1          Amazon
#
# [5 rows x 33 columns]

# %%
looker_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154 entries, 0 to 153
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Display Order          154 non-null    float64
#  1   Product Details        154 non-null    object
#  2   ASIN                   154 non-null    object
#  3   URL                    154 non-null    object
#  4   Image URL              154 non-null    object
#  5   Brand                  154 non-null    object
#  6   Price  $               154 non-null    object
#  7   Parent Level Sales     154 non-null    object
#  8   ASIN Sales             154 non-null    object
#  9   Recent Purchases       96 non-null     object
#  10  Parent Level Revenue   154 non-null    object
#  11  ASIN Revenue           154 non-null    object
#  12  Title Char. Count      154 non-null    int64
#  13  BSR                    150 non-null    object
#  14  Seller Country/Region  150 non-null    object
#  15  Fees  $                152 non-null    float64
#  16  Active Sellers         154 non-null    int64
#  17  Ratings                149 non-null    float64
#  18  Review Count           154 non-null    object
#  19  Images                 149 non-null    float64
#  20  Review velocity        146 non-null    object
#  21  Buy Box                152 non-null    object
#  22  Category               154 non-null    object
#  23  Size Tier              153 non-null    object
#  24  Fulfillment            152 non-null    object
#  25  Dimensions             153 non-null    object
#  26  Weight                 153 non-null    float64
#  27  ABA Most Clicked       0 non-null      float64
#  28  Creation Date          154 non-null    object
#  29  Sponsored              154 non-null    object
#  30  Best Seller            154 non-null    object
#  31  Seller Age (mo)        154 non-null    int64
#  32  Seller                 152 non-null    object
# dtypes: float64(6), int64(3), object(24)
# memory usage: 39.8+ KB
